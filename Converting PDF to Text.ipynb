# %% [markdown]
# # Extract Financial Statement Values
#
# Financial statement analysis is critical to every organization to enable companies to make better economic decisions that yields more income in the future. For a given financial statement, a rulebook is followed to extract the values associated with accrual, audit status, balance sheet, measurement date and pension plans as shown (refer rulebook & sample data here)
#
# ## Task:
#
# Build an NLP model which analyzes each document, looks for relevant financial terms (described below)
#
# The NLP Model should learn on Documents available under Training data folder using Rules listed here
#
# Apply the same model on Test Data documents to extract relevant financial information
#
# The results need to be updated & uploaded in the sheet provided: ‘Results.csv’ (download dataset)
#
# Note: No training labels are explicitly available for this problem statement. You will be able to test your model's accuracy by submitting values extracted for Test data.
#
# ## Data Description:
#
# Columns
#
# Description of Values
#
# Credit Name, State, Security ID, Org ID, FYE
#
# Identifiers from Documents provided to you already in “Results.csv”
#
# Accounting Basis
#
# Identify ‘Basis of Accounting’ as [‘Accrual’, ‘Cash’, ‘Modified Accrual’, ‘Modified Cash’, ‘Regulatory’]
#
# Pension Plan 1 Name*
#
# Pension Plan Identifier for Pension Plan with highest Total Pension Liability (0 if no date is specified)
#
# Pension Plan 1 Measurement Date
#
# Reporting Date for Pension Plan 1 (0 if no date is specified) [DD/MM/YYYY]
#
# Pension Plan 1 Total Pension Liability
#
# Total Pension Plan liability for Pension Plan 1 (0 if no liability is specified) [int64]
#
# Balance Sheet Cash
#
# Total value of Balance sheet-Governmental funds under ‘Cash & Cash Equivalents’ row. This will include all other row items as well which have been highlighted in the rules for cash and cash equivalent.  (0 if no balance sheet amount is specified) [int64]
#
# Pension Plan 2 Name*
#
# Pension Plan Identifier for Pension Plan with second highest Total Pension Liability (0 if no date is specified)
#
# Pension Plan 2 Measurement Date
#
# Reporting Date for Pension Plan 1 (0 if no date is specified) [DD/MM/YYYY]
#
# Pension Plan 2 Total Pension Liability
#
# Total Pension Plan liability for Pension Plan 1 (0 if no date is specified) [int64]
#
# Note: *- Map Pension Plan Names to Industry Standards as specified here
#
# ### Data Volume:
#
# Train Data: 479 Documents, 1.5GB
#
# Test Data: 98 Documents, 373.7MB
#
# Submission Format: You need to update Results.csv provided here, with your predictions and upload it online.
#
# Data Files: Download Dataset (~1.7GB)
#
# Evaluation Metric:
#
# [ML_Model] accuracy_score
#
#
# [Offline] Source Code, Models/Logic used

# %%
import pandas as pd
import numpy as np

# %%
res=pd.read_csv('../Results5cf9666.csv')
res.head()
# Out:
#      For Lookup  Year      Credit Name State  Security ID  Org ID         FYE  \
# 0  1013737_2016  2016        Jeannette    PA      1013737    8612  31/12/2016
# 1  1028564_2016  2016        Dickinson    ND      1028564   12020  31/12/2016
# 2   711506_2016  2016  Rawlins County     KS       711506  494151  31/12/2016
# 3   702336_2016  2016     Stone County    MO       702336  326056  31/12/2016
# 4  1029684_2017  2017        Anchorage    AK      1029684   27613  31/12/2017
#
#    Accounting Basis  Pension Plan 1 Name  Pension Plan 1 Measurement Date  \
# 0               NaN                  NaN                              NaN
# 1               NaN                  NaN                              NaN
# 2               NaN                  NaN                              NaN
# 3               NaN                  NaN                              NaN
# 4               NaN                  NaN                              NaN
#
#    Pension Plan 1 Total Pension Liability  Balance Sheet Cash  \
# 0                                     NaN                 NaN
# 1                                     NaN                 NaN
# 2                                     NaN                 NaN
# 3                                     NaN                 NaN
# 4                                     NaN                 NaN
#
#    Pension Plan 2 Name  Pension Plan 2 Measurement Date  \
# 0                  NaN                              NaN
# 1                  NaN                              NaN
# 2                  NaN                              NaN
# 3                  NaN                              NaN
# 4                  NaN                              NaN
#
#    Pension Plan 2 Total Pension Liability
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN

# %% [markdown]
# ## Sample submission with hard coded values

# %%
p=['GA_Muni Asso',
'CO_Nonemer Emp Ret Sys',
'MI_Gen Ret Sys',
'MO_Polman & Firemen Pen Plan',
'TX_Firemen Reli & Ret Fund']

import random
random.seed(1994)
random.choice(p)
# Out:
# 'MO_Polman & Firemen Pen Plan'

# %%
pen1=[]
pen2=[]
for j in range(98):
    pen1.append(random.choice(p))
    pen2.append(random.choice(p))

# %%
res.shape
# Out:
# (98, 15)

# %%
res['Accounting Basis']='Accrual'
res['Pension Plan 1 Total Pension Liability']=0
res['Pension Plan 2 Total Pension Liability']=0
res['Balance Sheet Cash']=0

res['Pension Plan 1 Name']=pen1
res['Pension Plan 2 Name']=pen2
res['Pension Plan 1 Measurement Date']='June 30, 2017'
res['Pension Plan 2 Measurement Date']='June 30, 2017'

# %%
res.head()
# Out:
#      For Lookup  Year      Credit Name State  Security ID  Org ID         FYE  \
# 0  1013737_2016  2016        Jeannette    PA      1013737    8612  31/12/2016
# 1  1028564_2016  2016        Dickinson    ND      1028564   12020  31/12/2016
# 2   711506_2016  2016  Rawlins County     KS       711506  494151  31/12/2016
# 3   702336_2016  2016     Stone County    MO       702336  326056  31/12/2016
# 4  1029684_2017  2017        Anchorage    AK      1029684   27613  31/12/2017
#
#   Accounting Basis           Pension Plan 1 Name  \
# 0          Accrual  MO_Polman & Firemen Pen Plan
# 1          Accrual  MO_Polman & Firemen Pen Plan
# 2          Accrual    TX_Firemen Reli & Ret Fund
# 3          Accrual                  GA_Muni Asso
# 4          Accrual                MI_Gen Ret Sys
#
#   Pension Plan 1 Measurement Date  Pension Plan 1 Total Pension Liability  \
# 0                   June 30, 2017                                       0
# 1                   June 30, 2017                                       0
# 2                   June 30, 2017                                       0
# 3                   June 30, 2017                                       0
# 4                   June 30, 2017                                       0
#
#    Balance Sheet Cash     Pension Plan 2 Name Pension Plan 2 Measurement Date  \
# 0                   0          MI_Gen Ret Sys                   June 30, 2017
# 1                   0          MI_Gen Ret Sys                   June 30, 2017
# 2                   0  CO_Nonemer Emp Ret Sys                   June 30, 2017
# 3                   0          MI_Gen Ret Sys                   June 30, 2017
# 4                   0          MI_Gen Ret Sys                   June 30, 2017
#
#    Pension Plan 2 Total Pension Liability
# 0                                       0
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       0

# %%
res.columns
# Out:
# Index(['For Lookup', 'Year', 'Credit Name', 'State', 'Security ID', 'Org ID',
#        'FYE', 'Accounting Basis', 'Pension Plan 1 Name',
#        'Pension Plan 1 Measurement Date',
#        'Pension Plan 1 Total Pension Liability', 'Balance Sheet Cash',
#        'Pension Plan 2 Name', 'Pension Plan 2 Measurement Date',
#        'Pension Plan 2 Total Pension Liability'],
#       dtype='object')

# %%
res.to_csv('newSub2.csv',index=False)

# %% [markdown]
# ### gave around 12-14.XX score

# %%
res.set_index(['For Lookup', 'Year', 'Credit\nName', 'State', 'Security\nID',
       'Org\nID', 'FYE']).to_csv('withIndex2.csv')

# %%
res[['Credit\nName', 'State', 'Security\nID',
       'Org\nID', 'FYE', 'Accounting Basis', 'Pension Plan 1 Name',
       'Pension Plan 1 Measurement Date',
       'Pension Plan 1 Total Pension Liability', 'Balance Sheet Cash',
       'Pension Plan 2 Name', 'Pension Plan 2 Measurement Date',
       'Pension Plan 2 Total Pension Liability']].to_csv('Resultsq2.csv',index=False)

# %%
### Installing packages

# %%
# !pip install PyPDF2
# Out:
# Collecting PyPDF2
#   Downloading https://files.pythonhosted.org/packages/b4/01/68fcc0d43daf4c6bdbc6b33cc3f77bda531c86b174cac56ef0ffdb96faab/PyPDF2-1.26.0.tar.gz (77kB)
#     100% |████████████████████████████████| 81kB 642kB/s ta 0:00:01
# Building wheels for collected packages: PyPDF2
#   Running setup.py bdist_wheel for PyPDF2 ... done
#   Stored in directory: /Users/rajat.ranjan/Library/Caches/pip/wheels/53/84/19/35bc977c8bf5f0c23a8a011aa958acd4da4bbd7a229315c1b7
# Successfully built PyPDF2
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-1.26.0

# %% [markdown]
# ## All test files

# %%
import os
print(os.listdir('Test Data/Jeannette_PA_8612_G O Municipality & County_City _2016.pdf'))
# Out:
# ['Minneapolis_KS_523347_G O Municipality & County_City _2017.pdf', 'Pima Cnty_AZ_1422_G O Municipality & County_County_2018.pdf', 'Audubon Cnty_IA_303832_G O Municipality & County_County_2017.pdf', 'Ipswich Twn_MA_340179_G O Municipality & County_Town_2018.pdf', 'Oro Vy_AZ_20742_G O Municipality & County_Town_2017.pdf', 'Jeannette_PA_8612_G O Municipality & County_City _2016.pdf', 'Yonkers_NY_3562_G O Municipality & County_City _2018.pdf', 'River Trails Pk Dist_IL_347152_G O Municipality & County_Special District_2017.pdf', 'South Florida Wtr Mgt Dist_FL_13376_G O Municipality & County_Special District_2017.pdf', 'Garfield Township_MI_521870_G O Municipality & County_Town_2017.pdf', 'Dodge City_KS_15059_G O Municipality & County_City _2017.pdf', 'Annapolis_MD_1784_G O Municipality & County_City_2018.pdf', 'Sussex Cnty_DE_13218_G O Municipality & County_County_2018.pdf', 'Talladega_AL_8999_G O Municipality & County_City_2017.pdf', 'Kitsap Cnty_WA_11962_G O Municipality & County_County_2017.pdf', 'Jefferson Cnty  GO _AL_10928_G O Municipality & County_County_2017.pdf', 'Sweetwater Cnty_WY_15662_G O Municipality & County_County_2017.pdf', 'East Haddam_CT_12833_G O Municipality & County_Town_2018.pdf', 'Pine Bluff_AR_14783_G O Municipality & County_City _2017.pdf', 'Sharon_PA_26199_G O Municipality & County_City_2017.pdf', 'Mason Creek Util Dist_TX_7162_G O Municipality & County_Special District_2018.pdf', 'El Paso De Robles  aka Paso Robles _CA_17712_G O Municipality & County_City _2018.pdf', 'Geneva County_AL_571349_G O Municipality & County_County_2017.pdf', 'La Paz Cnty_AZ_372467_G O Municipality & County_County_2017.pdf', 'Angleton Danbury Hosp Dist_TX_15837_G O Municipality & County_Special District_2017.pdf', 'Crestview_FL_2916_G O Municipality & County_City_2017.pdf', 'Shelby Cnty_AL_21033_G O Municipality & County_County_2017.pdf', 'Smithfield_RI_7948_G O Municipality & County_Town_2018.pdf', 'Fond Du Lac_WI_6846_G O Municipality & County_City_2017.pdf', 'Clay Twp_MI_345734_G O Municipality & County_Town_2018.pdf', 'Hot Springs_SD_553948_G O Municipality & County_City _2017.pdf', 'Centerville City_UT_467721_G O Municipality & County_City _2018.pdf', 'Lake Benton_MN_23324_G O Municipality & County_City _2017.pdf', 'Seguin_TX_11139_G O Municipality & County_City_2018.pdf', 'Tamarac_FL_10088_G O Municipality & County_City_2018.pdf', 'Greenfield_MA_23202_G O Municipality & County_Town_2017.pdf', 'Stone County_MO_326056_G O Municipality & County_County_2016.pdf', 'Williamson Cnty Mun Util Dist 11_TX_479501_G O Municipality & County_special District_2018.pdf', 'Pleasant Grove_UT_27947_G O Municipality & County_City _2018.pdf', 'Chelan Cnty_WA_15594_G O Municipality & County_County_2017.pdf', 'Utica City_VT_17524_G O Municipality & County_City_2018.pdf', 'Summit Cnty_OH_5816_G O Municipality & County_County_2017.pdf', 'Commerce_CA_379093_G O Municipality & County_City_2018.pdf', 'St Johns Cnty_FL_2840_G O Municipality & County_County_2017.pdf', 'Harris Cnty Mun Util Dist #168_TX_26773_G O Municipality & County_Special District_2018.Pdf.pdf', 'Moscow_ID_326597_G O Municipality & County_City _2017.pdf', 'Summerdale_AL_405045_G O Municipality & County_City_2017.pdf', 'Fredericksburg_VA_6586_G O Municipality & County_City _2018.pdf', 'Valdez_AK_1129_G O Municipality & County_City_2017.pdf', 'Milpitas_CA_344039_G O Municipality & County_City_2018.pdf', 'Harris Cnty Mun Util Dist 354_TX_326743_G O Municipality & County_Special District_2017.pdf', 'Killingly Twn_CT_550_G O Municipality & County_Town_2017.pdf', 'Ste. Genevieve_MO_321475_G O Municipality & County_City _2017.pdf', 'Las Cruces_NM_2956_G O Municipality & County_City _2018.pdf', 'Joliet Pk Dist_IL_12617_G O Municipality & County_Special District_2017.pdf', 'Grand Meadow_MN_490158_G O Municipality & County_City _2017.pdf', 'Denver City Cnty_CO_1025_G O Municipality & County_County_2017.pdf', 'Dickinson_ND_12020_G O Municipality & County_City_2016.pdf', 'Utah Cnty_UT_16030_G O ...

# %%
res[res.Year==2016]
# Out:
#       For Lookup  Year      Credit Name State  Security ID  Org ID  \
# 0   1013737_2016  2016        Jeannette    PA      1013737    8612
# 1   1028564_2016  2016        Dickinson    ND      1028564   12020
# 2    711506_2016  2016  Rawlins County     KS       711506  494151
# 3    702336_2016  2016     Stone County    MO       702336  326056
# 86  1022225_2016  2016           Buford    GA      1022225   14231
#
#            FYE Accounting Basis  Pension Plan 1 Name  \
# 0   31/12/2016          Accrual                  NaN
# 1   31/12/2016          Accrual                  NaN
# 2   31/12/2016          Accrual                  NaN
# 3   31/12/2016          Accrual                  NaN
# 86   6/30/2016          Accrual                  NaN
#
#     Pension Plan 1 Measurement Date  Pension Plan 1 Total Pension Liability  \
# 0                               NaN                                       0
# 1                               NaN                                       0
# 2                               NaN                                       0
# 3                               NaN                                       0
# 86                              NaN                                       0
#
#     Balance Sheet Cash  Pension Plan 2 Name  Pension Plan 2 Measurement Date  \
# 0                    0                  NaN                              NaN
# 1                    0                  NaN                              NaN
# 2                    0                  NaN                              NaN
# 3                    0                  NaN                              NaN
# 86                   0                  NaN                              NaN
#
#     Pension Plan 2 Total Pension Liability
# 0                                        0
# 1                                        0
# 2                                        0
# 3                                        0
# 86                                       0

# %%
# !pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading https://files.pythonhosted.org/packages/8a/fd/6e8746e6965d1a7ea8e97253e3d79e625da5547e8f376f88de5d024bacb9/pdfminer.six-20181108-py2.py3-none-any.whl (5.6MB)
#     100% |████████████████████████████████| 5.6MB 302kB/s ta 0:00:01
# Requirement already satisfied: six in /Users/rajat.ranjan/anaconda3/lib/python3.7/site-packages (from pdfminer.six) (1.12.0)
# Requirement already satisfied: sortedcontainers in /Users/rajat.ranjan/anaconda3/lib/python3.7/site-packages (from pdfminer.six) (2.1.0)
# Collecting pycryptodome (from pdfminer.six)
#   Downloading https://files.pythonhosted.org/packages/b7/94/74a003a7dfbffed6064679e9f3c87a7b7866c652dc3c647ca2a01822d7ca/pycryptodome-3.8.2-cp37-cp37m-macosx_10_6_intel.whl (10.1MB)
#     100% |████████████████████████████████| 10.1MB 945kB/s ta 0:00:01
# Installing collected packages: pycryptodome, pdfminer.six
# Successfully installed pdfminer.six-20181108 pycryptodome-3.8.2

# %% [markdown]
# ### Installing packages

# %%
# !pip install PIL
# !pip install pytesseract
# !pip install pdf2image
# Out:
# Collecting PIL
#   Could not find a version that satisfies the requirement PIL (from versions: )
# No matching distribution found for PIL
# Collecting pytesseract
#   Downloading https://files.pythonhosted.org/packages/1d/40/3f72d13d0f347bf688ff189b6d6bb369125c0bed9ed4b15e7f20c65123a8/pytesseract-0.2.7.tar.gz (169kB)
#     100% |████████████████████████████████| 174kB 1.6MB/s ta 0:00:01
# Requirement already satisfied: Pillow in /Users/rajat.ranjan/anaconda3/lib/python3.7/site-packages (from pytesseract) (5.3.0)
# Building wheels for collected packages: pytesseract
#   Running setup.py bdist_wheel for pytesseract ... done
#   Stored in directory: /Users/rajat.ranjan/Library/Caches/pip/wheels/cd/4a/30/998e01b892300ba0ccce7b806b6e889794605a384dac81a49a
# Successfully built pytesseract
# Installing collected packages: pytesseract
# Successfully installed pytesseract-0.2.7
# Collecting pdf2image
#   Downloading https://files.pythonhosted.org/packages/04/21/64583455a8e41b2838a51789807889d947575b828f816a0ade1160c1e2c4/pdf2image-1.6.0.tar.gz
# Requirement already satisfied: pillow in /Users/rajat.ranjan/anaconda3/lib/python3.7/site-packages (from pdf2image) (5.3.0)
# Building wheels for collected packages: pdf2image
#   Running setup.py bdist_wheel for pdf2image ... done
#   Stored in directory: /Users/rajat.ranjan/Library/Caches/pip/wheels/f5/1f/44/7434780055b8210787a0ddc3f8454d49a420f15936331b2990
# Successfully built pdf2image
# Installing collected packages: pdf2image
# Successfully installed pdf2image-1.6.0

# %%
import os
test_pdf=os.listdir('Test Data')
test_pdf
# Out:
# ['Minneapolis_KS_523347_G O Municipality & County_City _2017.pdf',
#  'Pima Cnty_AZ_1422_G O Municipality & County_County_2018.pdf',
#  'Audubon Cnty_IA_303832_G O Municipality & County_County_2017.pdf',
#  'Ipswich Twn_MA_340179_G O Municipality & County_Town_2018.pdf',
#  'Oro Vy_AZ_20742_G O Municipality & County_Town_2017.pdf',
#  'Jeannette_PA_8612_G O Municipality & County_City _2016.pdf',
#  'Yonkers_NY_3562_G O Municipality & County_City _2018.pdf',
#  'River Trails Pk Dist_IL_347152_G O Municipality & County_Special District_2017.pdf',
#  'South Florida Wtr Mgt Dist_FL_13376_G O Municipality & County_Special District_2017.pdf',
#  'Garfield Township_MI_521870_G O Municipality & County_Town_2017.pdf',
#  'Dodge City_KS_15059_G O Municipality & County_City _2017.pdf',
#  'Annapolis_MD_1784_G O Municipality & County_City_2018.pdf',
#  '.DS_Store',
#  'Sussex Cnty_DE_13218_G O Municipality & County_County_2018.pdf',
#  'Talladega_AL_8999_G O Municipality & County_City_2017.pdf',
#  'Kitsap Cnty_WA_11962_G O Municipality & County_County_2017.pdf',
#  'Jefferson Cnty  GO _AL_10928_G O Municipality & County_County_2017.pdf',
#  'Sweetwater Cnty_WY_15662_G O Municipality & County_County_2017.pdf',
#  'East Haddam_CT_12833_G O Municipality & County_Town_2018.pdf',
#  'Pine Bluff_AR_14783_G O Municipality & County_City _2017.pdf',
#  'Sharon_PA_26199_G O Municipality & County_City_2017.pdf',
#  'Mason Creek Util Dist_TX_7162_G O Municipality & County_Special District_2018.pdf',
#  'Geneva County_AL_571349_G O Municipality & County_County_2017.pdf',
#  'La Paz Cnty_AZ_372467_G O Municipality & County_County_2017.pdf',
#  'Angleton Danbury Hosp Dist_TX_15837_G O Municipality & County_Special District_2017.pdf',
#  'Crestview_FL_2916_G O Municipality & County_City_2017.pdf',
#  'Shelby Cnty_AL_21033_G O Municipality & County_County_2017.pdf',
#  'Smithfield_RI_7948_G O Municipality & County_Town_2018.pdf',
#  'Fond Du Lac_WI_6846_G O Municipality & County_City_2017.pdf',
#  'Clay Twp_MI_345734_G O Municipality & County_Town_2018.pdf',
#  'Hot Springs_SD_553948_G O Municipality & County_City _2017.pdf',
#  'Centerville City_UT_467721_G O Municipality & County_City _2018.pdf',
#  'Lake Benton_MN_23324_G O Municipality & County_City _2017.pdf',
#  'Seguin_TX_11139_G O Municipality & County_City_2018.pdf',
#  'Tamarac_FL_10088_G O Municipality & County_City_2018.pdf',
#  'Greenfield_MA_23202_G O Municipality & County_Town_2017.pdf',
#  'Stone County_MO_326056_G O Municipality & County_County_2016.pdf',
#  'Williamson Cnty Mun Util Dist 11_TX_479501_G O Municipality & County_special District_2018.pdf',
#  'Pleasant Grove_UT_27947_G O Municipality & County_City _2018.pdf',
#  'Chelan Cnty_WA_15594_G O Municipality & County_County_2017.pdf',
#  'Utica City_VT_17524_G O Municipality & County_City_2018.pdf',
#  'Summit Cnty_OH_5816_G O Municipality & County_County_2017.pdf',
#  'Commerce_CA_379093_G O Municipality & County_City_2018.pdf',
#  'St Johns Cnty_FL_2840_G O Municipality & County_County_2017.pdf',
#  'Harris Cnty Mun Util Dist #168_TX_26773_G O Municipality & County_Special District_2018.Pdf.pdf',
#  'Moscow_ID_326597_G O Municipality & County_City _2017.pdf',
#  'Summerdale_AL_405045_G O Municipality & County_City_2017.pdf',
#  'Fredericksburg_VA_6586_G O Municipality & County_City _2018.pdf',
#  'Valdez_AK_1129_G O Municipality & County_City_2017.pdf',
#  'Milpitas_CA_344039_G O Municipality & County_City_2018.pdf',
#  'Harris Cnty Mun Util Dist 354_TX_326743_G O Municipality & County_Special District_2017.pdf',
#  'Killingly Twn_CT_550_G O Municipality & County_Town_2017.pdf',
#  'Ste. Genevieve_MO_321475_G O Municipality & County_City _2017.pdf',
#  'Las Cruces_NM_2956_G O Municipality & County_City _2018.pdf',
#  'Joliet Pk Dist_IL_12617_G O Municipality & County_Special District_2017.pdf',
#  'Grand Meadow_MN_490158_G O Municipality & County_City _2017.pdf',
#  'Denver City Cnty_CO_1025_G O Municipality & County_County_2017.pdf',
#  'Dickinson_ND_12020_G O Municipality & County_City_2016.pdf',
#  'Utah Cnty_UT_16030_G O Municipality & County_County_2017.pdf',
#  'Travis Cnty Mun Util Dist No.11_TX_557386_G O Municipality & County_special District_2018.Pdf.pdf',
#  'Ansonia_CT_300854_G O Municipality & County_City _2018.pdf',
#  'Farmers Branch_TX_22559_G O Municipality & County_City_2018.pdf',
#  'Buford_GA_14231_G O Municipality & County_City _2016.pdf',
#  'Virginia Peninsula Regl Jail Auth_VA_303122_G O Municipality & County_Special District_2017.pdf',
#  'Woods Cross_UT_20994_G O Municipality & County_City_2018.pdf',
#  'Grundy Cnty_IL_362269_G O Municipality & County_County_2018.pdf',
#  'St. Bernard Parish_LA_89_G O Municipality & County_County_2017.pdf',
#  'Jones Cnty_MS_21281_G O Municipality & County_County_2017.pdf',
#  'Clay Cnty_KS_475061_G O Municipality & County_County_2017.pdf',
#  'Sea Isle City_NJ_10889_G O Municipality & County_City_2017.pdf',
#  'Ocean City_NJ_4115_G O Municipality & County_City_2017.pdf',
#  'Burleigh Cnty_ND_10620_G O Municipality & County_County_2017.pdf',
#  'Belmont Cnty_OH_13654_G O Municipality & County_County_2017.pdf',
#  'Snoqualmie_WA_367048_G O Municipality & County_City_2017.pdf',
#  'Pointe Coupee Parish_LA_14599_G O Municipality & County_County_2017.pdf',
#  'Hidalgo Cnty Dr Dist 1_TX_7635_G O Municipality & County_Special District_2017.pdf',
#  'Shell Rock River Watershed District_MN_607184_G O Municipality & County_Special District_2017.pdf',
#  'Gwinnett Cnty_GA_9457_G O Municipality & County_County_2017.pdf',
#  'Bath Charter Twp_MI_378353_G O Municipality & County_Town_2017.pdf',
#  'Cordova Rec and Park_CA_623440_G O Municipality & County_Special District_2017.pdf',
#  'Fillmore Cnty_NE_491999_G O Municipality & County_County_2017.pdf',
#  'Surry Cnty_NC_3385_G O Municipality & County_County_2018.pdf',
#  'Providence_RI_7947_G O Municipality & County_City_2018.pdf',
#  'St Louis Regl Arpt Auth_IL_333960_G O Municipality & County_Special District_2018.pdf',
#  'Plaquemine_LA_322719_G O Municipality & County_City _2017.pdf',
#  'Rawlins County_KS_494151_G O Municipality & County_County_2016.pdf',
#  'Texarkana_AR_2518_G O Municipality & County_City_2017.pdf',
#  'Wadsworth_OH_25271_G O Municipality & County_City _2017.pdf',
#  'Wallace County_KS_485563_G O Municipality & County_County_2017.pdf',
#  'Fayetteville_AR_1499_G O Municipality & County_City_2017.pdf',
#  'Reno_NV_4397_G O Municipality & County_City_2018.pdf',
#  'Kalispell _MT_361330_G O Municipality & County_City _2018.pdf',
#  'NOVATO_CA_20829_G O Municipality & County_City _2017.pdf',
#  'Red Oak_TX_13782_G O Municipality & County_City_2017.pdf',
#  'Nassau Cnty_NY_3677_G O Municipality & County_County_2017.pdf',
#  'Salem_NH_12414_G O Municipality & County_Town_2017.pdf',
#  'Anchorage_AK_27613_G O Municipality & County_City_2017.pdf',
#  'Spring Creek Utility District_TX_322417_G O Municipality & County_Special District_2018.pdf']

# %%
os.getcwd()
os.chdir('/Users/rajat.ranjan/Desktop/ML/CIRSIL/Crisil Challenge Data/')

# %% [markdown]
# ## Importing the PDF
# ## Converting them to images with pdf2image
# ## using pytessaract converted Images to String and save into text file

# %%
from PIL import Image 
import pytesseract 
import sys 
from pdf2image import convert_from_path 
import os 
  
for pdf in test_pdf:
    print('for ----',pdf)
    PDF_file = "Test Data/"+pdf
    pages = convert_from_path(PDF_file, 500) 
    path=os.getcwd()+'/'+pdf.split('&')[0]
 
    try:
        # Create target Directory
        os.mkdir(pdf.split('&')[0])
        print(" Created ") 
    except FileExistsError:
        print('error')
    os.chdir(path)
    # Counter to store images of each page of PDF to image 
    image_counter = 1
    # Iterate through all the pages stored above 
    for page in pages: 
        # Declaring filename for each page of PDF as JPG 
        # For each page, filename will be: 
        # PDF page 1 -> page_1.jpg 
        # PDF page 2 -> page_2.jpg 
        # PDF page 3 -> page_3.jpg 
        # .... 
        # PDF page n -> page_n.jpg 
        filename = "page_"+str(image_counter)+".jpg"

        # Save the image of the page in system 
        page.save(filename, 'JPEG') 

        # Increment the counter to update filename 
        image_counter = image_counter + 1

    print('Part 2')
    #Part #2 - Recognizing text from the images using OCR 
    #'''
#         3
    # Variable to get count of total number of pages 
    filelimit = image_counter-1

    # Creating a text file to write the output 
    outfile = "out_text"+pdf.split('&')[0]+".txt"

    # Open the file in append mode so that  
    # All contents of all images are added to the same file 
    f = open(outfile, "a") 
    print('Part 3')
    # Iterate from 1 to total number of pages 
    for i in range(1, filelimit + 1): 

        # Set filename to recognize text from 
        # Again, these files will be: 
        # page_1.jpg 
        # page_2.jpg 
        # .... 
        # page_n.jpg 
        filename = "page_"+str(i)+".jpg"


        # Recognize the text as string in image using pytesserct 
        text = str(((pytesseract.image_to_string(Image.open(filename))))) 

        # The recognized text is stored in variable text 
        # Any string processing may be applied on text 
        # Here, basic formatting has been done: 
        # In many PDFs, at line ending, if a word can't 
        # be written fully, a 'hyphen' is added. 
        # The rest of the word is written in the next line 
        # Eg: This is a sample text this word here GeeksF- 
        # orGeeks is half on first line, remaining on next. 
        # To remove this, we replace every '-\n' to ''. 
        text = text.replace('-\n', '')     

        # Finally, write the processed text to the file. 
        f.write(text) 
        # Close the file after writing all the text. 
    os.chdir('/Users/rajat.ranjan/Desktop/ML/CIRSIL/Crisil Challenge Data/')
    f.close()
# Out:
# for ---- Geneva County_AL_571349_G O Municipality & County_County_2017.pdf
# error
# Part 2
# Part 3
# for ---- La Paz Cnty_AZ_372467_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Angleton Danbury Hosp Dist_TX_15837_G O Municipality & County_Special District_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Crestview_FL_2916_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Shelby Cnty_AL_21033_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Smithfield_RI_7948_G O Municipality & County_Town_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Fond Du Lac_WI_6846_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Clay Twp_MI_345734_G O Municipality & County_Town_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Hot Springs_SD_553948_G O Municipality & County_City _2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Centerville City_UT_467721_G O Municipality & County_City _2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Lake Benton_MN_23324_G O Municipality & County_City _2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Seguin_TX_11139_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Tamarac_FL_10088_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Greenfield_MA_23202_G O Municipality & County_Town_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Stone County_MO_326056_G O Municipality & County_County_2016.pdf
#  Created
# Part 2
# Part 3
# for ---- Williamson Cnty Mun Util Dist 11_TX_479501_G O Municipality & County_special District_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Pleasant Grove_UT_27947_G O Municipality & County_City _2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Chelan Cnty_WA_15594_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Utica City_VT_17524_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Summit Cnty_OH_5816_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Commerce_CA_379093_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- St Johns Cnty_FL_2840_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Harris Cnty Mun Util Dist #168_TX_26773_G O Municipality & County_Special District_2018.Pdf.pdf
#  Created
# Part 2
# Part 3
# for ---- Moscow_ID_326597_G O Municipality & County_City _2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Summerdale_AL_405045_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Fredericksburg_VA_6586_G O Municipality & County_City _2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Valdez_AK_1129_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Milpitas_CA_344039_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Harris Cnty Mun Util Dist 354_TX_326743_G O Municipality & County_Special District_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Killingly Twn_CT_550_G O Municipality & County_Town_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Ste. Genevieve_MO_321475_G O Municipality & County_City _2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Las Cruces_NM_2956_G O Municipality & County_City _2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Joliet Pk Dist_IL_12617_G O Municipality & County_Special District_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Grand Meadow_MN_490158_G O Municipality & County_City _2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Denver City Cnty_CO_1025_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Dickinson_ND_12020_G O Municipality & County_City_2016.pdf
#  Created
# Part 2
# Part 3
# for ---- Utah Cnty_UT_16030_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Travis Cnty Mun Util Dist No.11_TX_557386_G O Municipality & County_special District_2018.Pdf.pdf
#  Created
# Part 2
# Part 3
# for ---- Ansonia_CT_300854_G O Municipality & County_City _2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Farmers Branch_TX_22559_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Buford_GA_14231_G O Municipality & County_City _2016.pdf
#  Created
# Part 2
# Part 3
# for ---- Virginia Peninsula Regl Jail Auth_VA_303122_G O Municipality & County_Special District_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Woods Cross_UT_20994_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Grundy Cnty_IL_362269_G O Municipality & County_County_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- St. Bernard Parish_LA_89_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Jones Cnty_MS_21281_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Clay Cnty_KS_475061_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Sea Isle City_NJ_10889_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Ocean City_NJ_4115_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Burleigh Cnty_ND_10620_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Belmont Cnty_OH_13654_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Snoqualmie_WA_367048_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Pointe Coupee Parish_LA_14599_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Hidalgo Cnty Dr Dist 1_TX_7635_G O Municipality & County_Special District_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Shell Rock River Watershed District_MN_607184_G O Municipality & County_Special District_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Gwinnett Cnty_GA_9457_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Bath Charter Twp_MI_378353_G O Municipality & County_Town_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Cordova Rec and Park_CA_623440_G O Municipality & County_Special District_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Fillmore Cnty_NE_491999_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Surry Cnty_NC_3385_G O Municipality & County_County_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Providence_RI_7947_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- St Louis Regl Arpt Auth_IL_333960_G O Municipality & County_Special District_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Plaquemine_LA_322719_G O Municipality & County_City _2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Rawlins County_KS_494151_G O Municipality & County_County_2016.pdf
#  Created
# Part 2
# Part 3
# for ---- Texarkana_AR_2518_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Wadsworth_OH_25271_G O Municipality & County_City _2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Wallace County_KS_485563_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Fayetteville_AR_1499_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Reno_NV_4397_G O Municipality & County_City_2018.pdf
#  Created
# Part 2
# Part 3
# for ---- Kalispell _MT_361330_G O Municipality & County_City _2018.pdf
#  Created
# Part 2
# Part 3
# for ---- NOVATO_CA_20829_G O Municipality & County_City _2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Red Oak_TX_13782_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Nassau Cnty_NY_3677_G O Municipality & County_County_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Salem_NH_12414_G O Municipality & County_Town_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Anchorage_AK_27613_G O Municipality & County_City_2017.pdf
#  Created
# Part 2
# Part 3
# for ---- Spring Creek Utility District_TX_322417_G O Municipality & County_Special District_2018.pdf
#  Created
# Part 2
# Part 3

# %% [markdown]
# # This will create a directory as
#
# +PDF name
#
# --images
#
# -- pdf.txt
#
#
# +PDF name
#
# --images
#
# --pdf.txt
